# %%
import pandas as pd
import numpy as np

# %%
# Load the dataset
df = pd.read_csv('../data/complete_dataset_standardized.csv', sep=';')

# %%
df.head()
# Out:
#        pmid                                              title  \
# 0  10021369  Identification of APC2, a homologue of the ade...
# 1  10051005  A common MSH2 mutation in English and North Am...
# 2  10051007  Age of onset in Huntington disease : sex speci...
# 3    100562  Familial deficiency of the seventh component o...
# 4  10064668  Increased incidence of cancer in patients with...
#
#                                             abstract source  \
# 0  The adenomatous polyposis coli ( APC ) tumour-...   NCBI
# 1  The frequency , origin , and phenotypic expres...   NCBI
# 2  Age of onset ( AO ) of Huntington disease ( HD...   NCBI
# 3  The serum of a 29-year old woman with a recent...   NCBI
# 4  OBJECTIVE  Previous reports have suggested an ...   NCBI
#
#                          group Manual
# 0                  oncological    NaN
# 1     neurological|oncological    NaN
# 2                 neurological    NaN
# 3  neurological|cardiovascular      X
# ...

# %%
simplified_df = df[['title','abstract','group']]
simplified_df.head()
# Out:
#                                                title  \
# 0  Identification of APC2, a homologue of the ade...
# 1  A common MSH2 mutation in English and North Am...
# 2  Age of onset in Huntington disease : sex speci...
# 3  Familial deficiency of the seventh component o...
# 4  Increased incidence of cancer in patients with...
#
#                                             abstract  \
# 0  The adenomatous polyposis coli ( APC ) tumour-...
# 1  The frequency , origin , and phenotypic expres...
# 2  Age of onset ( AO ) of Huntington disease ( HD...
# 3  The serum of a 29-year old woman with a recent...
# 4  OBJECTIVE  Previous reports have suggested an ...
#
#                          group
# 0                  oncological
# 1     neurological|oncological
# 2                 neurological
# 3  neurological|cardiovascular
# 4     neurological|oncological

# %%
simplified_df.loc[:,'title'] = simplified_df['title'].str.lower()
simplified_df.loc[:,'abstract'] = simplified_df['abstract'].str.lower()

# %%
simplified_df.head()
# Out:
#                                                title  \
# 0  identification of apc2, a homologue of the ade...
# 1  a common msh2 mutation in english and north am...
# 2  age of onset in huntington disease : sex speci...
# 3  familial deficiency of the seventh component o...
# 4  increased incidence of cancer in patients with...
#
#                                             abstract  \
# 0  The adenomatous polyposis coli ( APC ) tumour-...
# 1  The frequency , origin , and phenotypic expres...
# 2  Age of onset ( AO ) of Huntington disease ( HD...
# 3  The serum of a 29-year old woman with a recent...
# 4  OBJECTIVE  Previous reports have suggested an ...
#
#                          group
# 0                  oncological
# 1     neurological|oncological
# 2                 neurological
# 3  neurological|cardiovascular
# 4     neurological|oncological
